# %%
pwd
# Out:
# '/global/scratch/projects/fc_wolflab/bbioinfo/empchase/checkm_all'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %%
datapath = '/global/scratch/projects/fc_wolflab/bbioinfo/empchase/checkm_all/outputtable.txt'

# %%
columns = None
data = []
with open(datapath, 'r') as f: 
    for line in f:
        line = line.strip()
        rawstats = line.split('  ')
        stats = [x.strip() for x in rawstats if x != '']
        # print(stats)
        # print(len(stats))
        if stats[0] == 'Bin Id':
            columns = [x.strip() for x in stats]
        else:
            data.append(stats)

print(columns)
print(data[:5])
# Out:
# ['Bin Id', 'Marker lineage', '# genomes', '# markers', '# marker sets', '0', '1', '2', '3', '4', '5+', 'Completeness', 'Contamination', 'Strain heterogeneity']
# [['Plate2_H5_Plate2_H5_contigs', 'k__Bacteria (UID203)', '5449', '103', '58', '0', '13', '24', '27', '19', '20', '100.00', '259.29', '60.00'], ['Plate2_H5_B_theta_BLANK_contigs', 'k__Bacteria (UID203)', '5449', '103', '58', '0', '13', '24', '27', '19', '20', '100.00', '259.29', '60.00'], ['Plate2_G4_B_ova_23575_contigs', 'k__Bacteria (UID203)', '5449', '103', '58', '0', '66', '31', '5', '1', '0', '100.00', '42.88', '46.15'], ['Plate2_G1_B_theta_22987_contigs', 'k__Bacteria (UID203)', '5449', '104', '58', '0', '46', '52', '6', '0', '0', '100.00', '68.84', '71.43'], ['Plate2_G12_B_theta_DH3941_contigs', 'k__Bacteria (UID203)', '5449', '104', '58', '0', '4', '91', '8', '1', '0', '100.00', '104.08', '83.47']]

# %%
df1 = pd.DataFrame(data, columns=columns)
df1.head()
# Out:
#                               Bin Id        Marker lineage # genomes  \
# 0        Plate2_H5_Plate2_H5_contigs  k__Bacteria (UID203)      5449
# 1    Plate2_H5_B_theta_BLANK_contigs  k__Bacteria (UID203)      5449
# 2      Plate2_G4_B_ova_23575_contigs  k__Bacteria (UID203)      5449
# 3    Plate2_G1_B_theta_22987_contigs  k__Bacteria (UID203)      5449
# 4  Plate2_G12_B_theta_DH3941_contigs  k__Bacteria (UID203)      5449
#
#   # markers # marker sets  0   1   2   3   4  5+ Completeness Contamination  \
# 0       103            58  0  13  24  27  19  20       100.00        259.29
# 1       103            58  0  13  24  27  19  20       100.00        259.29
# 2       103            58  0  66  31   5   1   0       100.00         42.88
# 3       104            58  0  46  52   6   0   0       100.00         68.84
# 4       104            58  0   4  91   8   1   0       100.00        104.08
#
#   Strain heterogeneity
# 0                60.00
# 1                60.00
# 2                46.15
# 3                71.43
# 4                83.47

# %%
# Function to format the position
def format_position(pos):
    # Use regex to capture the letter and the number
    import re
    match = re.match(r"([A-Z])(\d+)", pos)
    if match:
        letter = match.group(1)
        number = match.group(2).zfill(2)  # Zero-pad the number to 2 digits
        return f"{letter}{number}"
    return pos

# %%
df1[['Plate', 'Position', 'Genus', 'Species', 'Strain', 'type']] = df1['Bin Id'].str.split('_', expand=True)
df1['Plate'] = pd.to_numeric(df1['Plate'].str.strip('Plate'))
# df1.Position = df1.Position.str.replace(r"\D(\d)$", r"0\1")
# df1.Position = df1.Position.astype(str).str.zfill(2)
# df1['Position'] = df1['Position'].apply(lambda x: '{0:0>3}'.format(x))
df1['Position'] = df1['Position'].apply(format_position)
df1.iloc[:, 2:14] = df1.iloc[:, 2:14].apply(pd.to_numeric)
# df1['Contamination'] = pd.to_numeric(df1['Contamination'])
# df1['Strain heterogeneity'] = pd.to_numeric(df1['Strain heterogeneity'])
# df1['Completeness'] = pd.to_numeric(df1['Completeness'])


df1.head()
# Out:
#                               Bin Id        Marker lineage # genomes  \
# 0        Plate2_H5_Plate2_H5_contigs  k__Bacteria (UID203)      5449
# 1    Plate2_H5_B_theta_BLANK_contigs  k__Bacteria (UID203)      5449
# 2      Plate2_G4_B_ova_23575_contigs  k__Bacteria (UID203)      5449
# 3    Plate2_G1_B_theta_22987_contigs  k__Bacteria (UID203)      5449
# 4  Plate2_G12_B_theta_DH3941_contigs  k__Bacteria (UID203)      5449
#
#   # markers # marker sets  0   1   2   3   4  5+ Completeness Contamination  \
# 0       103            58  0  13  24  27  19  20        100.0        259.29
# 1       103            58  0  13  24  27  19  20        100.0        259.29
# 2       103            58  0  66  31   5   1   0        100.0         42.88
# 3       104            58  0  46  52   6   0   0        100.0         68.84
# 4       104            58  0   4  91   8   1   0        100.0        104.08
#
#   Strain heterogeneity  Plate Position   Genus Species   Strain     type
# 0                 60.0      2      H05  Plate2      H5  contigs     None
# 1                 60.0      2      H05       B   theta    BLANK  contigs
# 2                46.15      2      G04       B     ova    23575  contigs
# 3                71.43      2      G01       B   theta    22987  contigs
# 4                83.47      2      G12       B   theta   DH3941  contigs

# %%
df1['Contamination']
# Out:
# 0      259.29
# 1      259.29
# 2       42.88
# 3       68.84
# 4      104.08
#         ...
# 192     39.55
# 193      3.02
# 194       0.5
# 195       0.0
# 196       0.0
# Name: Contamination, Length: 197, dtype: object

# %%
lineage_values = df1['Marker lineage'].value_counts().to_frame().reset_index()
# print(lineage_values.head())
ax= sns.barplot(lineage_values, y='Marker lineage', x='count' )
ax.bar_label(ax.containers[0], fontsize=10);

# %%
dfconfirmed = pd.read_csv('/global/scratch/projects/fc_wolflab/bbioinfo/empchase/checkm_all/16sdata.txt', sep='\t')
# dfconfirmed['Confirmed'] = pd.to_numeric(dfconfirmed['Confirmed'])
dfconfirmed
# Out:
#     Plate Well              Species      Strain  Confirmed
# 0       1  A02          B. vulgatus       WH019          1
# 1       1  A05          B. vulgatus       WH515          1
# 2       1  A09          B. vulgatus    VPI-4245          1
# 3       1  A10             B. dorei   VPI-3776A          1
# 4       1  B05          B. vulgatus       WH516          1
# 5       1  E01          B. vulgatus     WH009ab          1
# 6       1  E02          B. vulgatus       WH108          1
# 7       1  F01          B. vulgatus       WH013          1
# 8       1  F05             B. dorei       WH607          1
# 9       1  F06        P. distasonis  VPI-C30-45          1
# 10      1  F09             B. dorei   VPI-6598B          1
# 11      1  F11        P. distasonis  VPI-BD6781          1
# 12      2  A06          B. vulgatus       23673          1
# 13      2  D08            B. ovatus       23736          1
# 14      2  F05            B. ovatus       23621          1
# 15      2  F06  B. thetaiotaomicron       23685          1
# 16      2  H10  B. thetaiotaomicron  TS33APG1.1          1
# 17      1  A11                  NaN         NaN         10
# 18      1  A12                  NaN         NaN         10
# 19      1  G02                  NaN         NaN         10
# 20      2  G01                  NaN         NaN         10
# 21      2  G02                  NaN         NaN         10
# 22      2  G03                  NaN         NaN         10
# 23      2  G04                  NaN         NaN         10
# 24      2  G08                  NaN         NaN         10
# 25      2  G10                  NaN         NaN         10
# 26      2  G11                  NaN         NaN         10
# 27      2  H04                  NaN         NaN         10
# 28      2  H05                  NaN         NaN         10
# 29      2  H07                  NaN         NaN         10
# 30      2  C02                  NaN         NaN         10
# 31      2  D04                  NaN         NaN         10
# 32      2  E03                  NaN         NaN         10
# 33      2  E04                  NaN         NaN         10
# 34      2  E06                  NaN         NaN         10
# 35      2  H10                  NaN         NaN         10
# 36      2  H08                  NaN         NaN         10
# 37      2  A12                  NaN         NaN         10
# 38      2  B02                  NaN         NaN         10

# %%
# September 18, 2024 interlude with bvbrc data
# bvbrc_dict={'A05':1.6, 'A10':0.2, 'A12':57.7, 'A11':52.6, 'G02':0.2, 'A02':0.2}
bvbrc_dict={'Well':['A05', 'A10', 'A12', 'A11', 'G02', 'A02'], 
           'bvbrc_pct_contam':[1.6, 0.2, 57.7, 52.6, 0.2, 0.2]}
bvbrc_df = pd.DataFrame.from_dict(bvbrc_dict)
bvbrc_df['Plate'] = 1
bvbrc_df
# Out:
#   Well  bvbrc_pct_contam  Plate
# 0  A05               1.6      1
# 1  A10               0.2      1
# 2  A12              57.7      1
# 3  A11              52.6      1
# 4  G02               0.2      1
# 5  A02               0.2      1

# %%
df_bvbrcxconfirmed = bvbrc_df.merge(dfconfirmed, on=['Well', 'Plate'])
df_bvbrcxconfirmed
# Out:
#   Well  bvbrc_pct_contam  Plate      Species     Strain  Confirmed
# 0  A05               1.6      1  B. vulgatus      WH515          1
# 1  A10               0.2      1     B. dorei  VPI-3776A          1
# 2  A12              57.7      1          NaN        NaN         10
# 3  A11              52.6      1          NaN        NaN         10
# 4  G02               0.2      1          NaN        NaN         10
# 5  A02               0.2      1  B. vulgatus      WH019          1

# %%
df_bvbrcxconfirmed['Confirmed'] = df_bvbrcxconfirmed['Confirmed'].replace({1:True, 10:False})
df_bvbrcxconfirmed
# Out:
# /tmp/ipykernel_1082256/3642767583.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_bvbrcxconfirmed['Confirmed'] = df_bvbrcxconfirmed['Confirmed'].replace({1:True, 10:False})
#   Well  bvbrc_pct_contam  Plate      Species     Strain  Confirmed
# 0  A05               1.6      1  B. vulgatus      WH515       True
# 1  A10               0.2      1     B. dorei  VPI-3776A       True
# 2  A12              57.7      1          NaN        NaN      False
# 3  A11              52.6      1          NaN        NaN      False
# 4  G02               0.2      1          NaN        NaN      False
# 5  A02               0.2      1  B. vulgatus      WH019       True

# %%
df2 = df1.merge(df_bvbrcxconfirmed, left_on=['Plate','Position'], right_on=['Plate','Well'], how='outer')
df2 = df2[['Marker lineage', '# genomes', '# markers', '# marker sets', 'Completeness', 'Contamination', 'Strain heterogeneity', 
        'Plate', 'Well', 'Confirmed', 'Species_y', 'Strain_y', '0',	'1',	'2',	'3',	'4',	'5+', 'bvbrc_pct_contam'	]]
df2.head()
# Out:
#                Marker lineage # genomes # markers # marker sets Completeness  \
# 0  o__Bacteroidales (UID2657)       160       491           269        99.26
# 1  o__Bacteroidales (UID2654)       163       485           265        99.25
# 2    g__Bacteroides (UID2691)        33       839           309        99.46
# 3    g__Bacteroides (UID2691)        33       839           309        99.14
# 4  o__Bacteroidales (UID2654)       163       486           266        99.25
#
#   Contamination Strain heterogeneity  Plate Well Confirmed    Species_y  \
# 0          2.01                 30.0      1  NaN       NaN          NaN
# 1           0.0                  0.0      1  A02      True  B. vulgatus
# 2          0.02                  0.0      1  NaN       NaN          NaN
# 3          1.96                47.06      1  NaN       NaN          NaN
# 4         23.05                21.85      1  A05      True  B. vulgatus
#
#   Strain_y  0    1   2  3  4 5+  bvbrc_pct_contam
# 0      NaN  2  481   7  1  0  0               NaN
# 1    WH019  2  483   0  0  0  0               0.2
# 2      NaN  3  835   1  0  0  0               NaN
# 3      NaN  4  818  17  0  0  0               NaN
# 4    WH515  2  380  98  5  1  0               1.6

# %%
df2[df2['bvbrc_pct_contam']==0.2]
# Out:
#                 Marker lineage # genomes # markers # marker sets Completeness  \
# 1   o__Bacteroidales (UID2654)       163       485           265        99.25
# 9   o__Bacteroidales (UID2654)       163       486           266        99.25
# 74  o__Bacteroidales (UID2654)       163       486           266        99.25
#
#    Contamination Strain heterogeneity  Plate Well Confirmed    Species_y  \
# 1            0.0                  0.0      1  A02      True  B. vulgatus
# 9            0.0                  0.0      1  A10      True     B. dorei
# 74          0.67                  0.0      1  G02     False          NaN
#
#      Strain_y  0    1  2  3  4 5+  bvbrc_pct_contam
# 1       WH019  2  483  0  0  0  0               0.2
# 9   VPI-3776A  2  484  0  0  0  0               0.2
# 74        NaN  2  479  5  0  0  0               0.2

# %%
bool_markers = {True:'s', False:'X'}
# sns.scatterplot(df2, y='bvbrc_pct_contam', x='Contamination', hue='Confirmed', legend=True, marker='x')
sns.scatterplot(df2, y='bvbrc_pct_contam', x='Contamination', legend=True, style='Confirmed', markers=bool_markers, alpha=0.5)
# plt.xscale('log')
# plt.yscale('log')
# Out:
# <Axes: xlabel='Contamination', ylabel='bvbrc_pct_contam'>

# %%
correlation_spearman = df2['bvbrc_pct_contam'].corr(df2['Contamination'], method='spearman')
print("Spearman correlation:", correlation_spearman)
# Out:
# Spearman correlation: 0.8932596002688613

# %%
pwd
# Out:
# '/global/scratch/projects/fc_wolflab/bbioinfo/empchase/checkm_all'

# %%
df3 = df2.copy(deep=True)
df3_confirmed = df3[df3['Confirmed']==1]
df3_confirmed['Confirmed']='Yes'

df3_confirmed
# Out:
# /tmp/ipykernel_1581803/3215761286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_confirmed['Confirmed']='Yes'
#                  Marker lineage # genomes # markers # marker sets  \
# 1    o__Bacteroidales (UID2654)       163       485           265
# 4    o__Bacteroidales (UID2654)       163       486           266
# 8                   root (UID1)      5656        56            24
# 9    o__Bacteroidales (UID2654)       163       486           266
# 16   o__Bacteroidales (UID2654)       163       486           266
# 48   o__Bacteroidales (UID2654)       163       486           266
# 49   o__Bacteroidales (UID2654)       163       486           266
# 60   o__Bacteroidales (UID2654)       163       486           266
# 64   o__Bacteroidales (UID2654)       163       486           266
# 65   o__Bacteroidales (UID2621)       198       427           260
# 69         k__Bacteria (UID203)      5449       104            58
# 71   o__Bacteroidales (UID2621)       198       427           260
# 104  o__Bacteroidales (UID2654)       163       485           265
# 143    g__Bacteroides (UID2691)        33       839           309
# 163    g__Bacteroides (UID2691)        33       839           309
# 164    g__Bacteroides (UID2691)        33       839           309
# 194    g__Bacteroides (UID2691)        33       839           309
#
#      Completeness  Contamination  Strain heterogeneity  Plate Well Confirmed  \
# 1           99.25           0.00                  0.00      1  A02       Yes
# 4           99.25          23.05                 21.85      1  A05       Yes
# 8          100.00         100.46                 63.79      1  A09       Yes
# 9           99.25           0.00                  0.00      1  A10       Yes
# 16          99.25           0.00                  0.00      1  B05       Yes
# 48          99.25           0.76                 75.00      1  E01       Yes
# 49          99.25           0.05                  0.00      1  E02       Yes
# 60          99.25           0.00                  0.00      1  F01       Yes
# 64          99.25           0.31                  0.00      1  F05       Yes
# 65          99.42           4.56                  0.00      1  F06       Yes
# 69         100.00          28.45                 48.48      1  F09       Yes
# 71          99.23          18.83                 42.11      1  F11       Yes
# 104         99.25           1.51                  0.00      2  A06       Yes
# 143         99.46           6.68                 55.77      2  D08       Yes
# 163         99.35           0.91                 33.33      2  F05       Yes
# 164         99.41          11.04                 20.79      2  F06       Yes
# 194         99.46           6.25                  3.08      2  H10       Yes
#
#                Species_y    Strain_y  0    1   2  3  4 5+
# 1            B. vulgatus       WH019  2  483   0  0  0  0
# 4            B. vulgatus       WH515  2  380  98  5  1  0
# 8            B. vulgatus    VPI-4245  0    0  55  1  0  0
# 9               B. dorei   VPI-3776A  2  484   0  0  0  0
# 16           B. vulgatus       WH516  2  484   0  0  0  0
# 48           B. vulgatus     WH009ab  2  480   4  0  0  0
# 49           B. vulgatus       WH108  2  483   1  0  0  0
# 60           B. vulgatus       WH013  2  484   0  0  0  0
# 64              B. dorei       WH607  2  482   2  0  0  0
# 65         P. distasonis  VPI-C30-45  2  404  21  0  0  0
# 69              B. dorei   VPI-6598B  0   81  18  5  0  0
# 71         P. distasonis  VPI-BD6781  3  360  58  6  0  0
# 104          B. vulgatus       23673  2  476   7  0  0  0
# 143            B. ovatus       23736  3  786  49  1  0  0
# 163            B. ovatus       23621  4  826   9  0  0  0
# 164  B. thetaiotaomicron       23685  4  742  89  4  0  0
# 194  B. thetaiotaomicron  TS33APG1.1  3  777  56  3  0  0

# %%
confcounts = df3_confirmed['Contamination'].value_counts().to_frame().reset_index()
confcounts['Confirmed']='Yes'
print(confcounts)
sns.histplot(df3_confirmed, x='Contamination', hue='Marker lineage')
# Out:
#     Contamination  count Confirmed
# 0            0.00      4       Yes
# 1           23.05      1       Yes
# 2          100.46      1       Yes
# 3            0.76      1       Yes
# 4            0.05      1       Yes
# 5            0.31      1       Yes
# 6            4.56      1       Yes
# 7           28.45      1       Yes
# 8           18.83      1       Yes
# 9            1.51      1       Yes
# 10           6.68      1       Yes
# 11           0.91      1       Yes
# 12          11.04      1       Yes
# 13           6.25      1       Yes
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Contamination', ylabel='Count'>

# %%
df3_confirmed.describe()
# Out:
#        Completeness  Contamination  Strain heterogeneity      Plate
# count     17.000000      17.000000             17.000000  17.000000
# mean      99.387059      11.932941             21.423529   1.294118
# std        0.244790      24.490959             26.405009   0.469668
# min       99.230000       0.000000              0.000000   1.000000
# 25%       99.250000       0.050000              0.000000   1.000000
# 50%       99.250000       1.510000              3.080000   1.000000
# 75%       99.420000      11.040000             42.110000   2.000000
# max      100.000000     100.460000             75.000000   2.000000

# %%
df3_nonconfirmed = df3[df3['Confirmed']==10]
df3_nonconfirmed['Confirmed'] = 'No'
df3_nonconfirmed
# Out:
# /tmp/ipykernel_1581803/1220424573.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3_nonconfirmed['Confirmed'] = 'No'
#                  Marker lineage # genomes # markers # marker sets  \
# 10                  root (UID1)      5656        56            24
# 11         k__Bacteria (UID203)      5449       103            58
# 74   o__Bacteroidales (UID2654)       163       486           266
# 110    g__Bacteroides (UID2691)        33       839           309
# 112    g__Bacteroides (UID2691)        33       839           309
# 125        k__Bacteria (UID203)      5449       104            58
# 139  o__Bacteroidales (UID2657)       160       492           269
# 150    g__Bacteroides (UID2691)        33       839           309
# 151    g__Bacteroides (UID2691)        33       839           309
# 152  o__Bacteroidales (UID2654)       163       486           266
# 172        k__Bacteria (UID203)      5449       104            58
# 173    g__Bacteroides (UID2691)        33       839           309
# 174    g__Bacteroides (UID2691)        33       839           309
# 175        k__Bacteria (UID203)      5449       103            58
# 179  o__Bacteroidales (UID2657)       160       492           269
# 181        k__Bacteria (UID203)      5449       104            58
# 182    g__Bacteroides (UID2691)        33       839           309
# 187  o__Bacteroidales (UID2657)       160       492           269
# 188        k__Bacteria (UID203)      5449       103            58
# 189        k__Bacteria (UID203)      5449       103            58
# 191    g__Bacteroides (UID2691)        33       839           309
# 192    g__Bacteroides (UID2691)        33       839           309
# 195    g__Bacteroides (UID2691)        33       839           309
#
#      Completeness  Contamination  Strain heterogeneity  Plate Well Confirmed  \
# 10         100.00         107.23                 67.19      1  A11        No
# 11          93.97          82.62                 16.04      1  A12        No
# 74          99.25           0.67                  0.00      1  G02        No
# 110         99.41          56.70                 62.98      2  A12        No
# 112         99.46           2.70                 17.39      2  B02        No
# 125        100.00          87.99                 66.67      2  C02        No
# 139         99.26          15.95                 17.07      2  D04        No
# 150         98.81           1.99                  4.17      2  E03        No
# 151         99.46           3.16                  2.94      2  E04        No
# 152         99.25          11.03                 11.32      2  E06        No
# 172        100.00          68.84                 71.43      2  G01        No
# 173         99.41           0.32                  0.00      2  G02        No
# 174         98.81          44.18                 34.29      2  G03        No
# 175        100.00          42.88                 46.15      2  G04        No
# 179         99.26           2.78                  8.33      2  G08        No
# 181        100.00         169.09                 52.10      2  G10        No
# 182         99.46          23.78                 44.44      2  G11        No
# 187         99.26           7.17                 36.11      2  H04        No
# 188        100.00         259.29                 60.00      2  H05        No
# 189        100.00         259.29                 60.00      2  H05        No
# 191         99.46           5.73                 48.98      2  H07        No
# 192         98.81          13.11                 42.02      2  H08        No
# 195         99.46           6.25                  3.08      2  H10        No
#
#     Species_y Strain_y  0    1    2   3   4  5+
# 10        NaN      NaN  0    0   52   4   0   0
# 11        NaN      NaN  4   20   70   6   3   0
# 74        NaN      NaN  2  479    5   0   0   0
# 110       NaN      NaN  4  413  380  39   2   1
# 112       NaN      NaN  3  813   23   0   0   0
# 125       NaN      NaN  0   34   63   7   0   0
# 139       NaN      NaN  2  416   70   4   0   0
# 150       NaN      NaN  6  809   24   0   0   0
# 151       NaN      NaN  3  806   28   2   0   0
# 152       NaN      NaN  2  439   41   4   0   0
# 172       NaN      NaN  0   46   52   6   0   0
# 173       NaN      NaN  4  832    3   0   0   0
# 174       NaN      NaN  5  532  231  57  13   1
# 175       NaN      NaN  0   66   31   5   1   0
# 179       NaN      NaN  2  478   12   0   0   0
# 181       NaN      NaN  0   14   46  31   9   4
# 182       NaN      NaN  3  664  150  22   0   0
# 187       NaN      NaN  2  456   33   1   0   0
# 188       NaN      NaN  0   13   24  27  19  20
# 189       NaN      NaN  0   13   24  27  19  20
# 191       NaN      NaN  3  787   49   0   0   0
# 192       NaN      NaN  5  723  107   4   0   0
# 195       NaN      NaN  3  777   56   3   0   0

# %%
nonconfcounts = df3_nonconfirmed['Contamination'].value_counts().to_frame().reset_index()
nonconfcounts['Confirmed']='No'
print(nonconfcounts)

sns.histplot(df3_nonconfirmed, x='Contamination', hue='Marker lineage')
# Out:
#     Contamination  count Confirmed
# 0          259.29      2        No
# 1          107.23      1        No
# 2            0.67      1        No
# 3           56.70      1        No
# 4            2.70      1        No
# 5           82.62      1        No
# 6           87.99      1        No
# 7           15.95      1        No
# 8            3.16      1        No
# 9            1.99      1        No
# 10          68.84      1        No
# 11           0.32      1        No
# 12          44.18      1        No
# 13          11.03      1        No
# 14          42.88      1        No
# 15           2.78      1        No
# 16          23.78      1        No
# 17         169.09      1        No
# 18           7.17      1        No
# 19           5.73      1        No
# 20          13.11      1        No
# 21           6.25      1        No
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Contamination', ylabel='Count'>

# %%
df3_nonconfirmed.describe()
# Out:
#        Completeness  Contamination  Strain heterogeneity      Plate
# count     23.000000      23.000000             23.000000  23.000000
# mean      99.252174      55.336957             33.595652   1.869565
# std        1.218579      77.371932             25.060365   0.344350
# min       93.970000       0.320000              0.000000   1.000000
# 25%       99.255000       4.445000              9.825000   2.000000
# 50%       99.460000      15.950000             36.110000   2.000000
# 75%      100.000000      75.730000             56.050000   2.000000
# max      100.000000     259.290000             71.430000   2.000000

# %%
totcounts = pd.concat([df3_confirmed, df3_nonconfirmed])
totcounts
# Out:
#                  Marker lineage # genomes # markers # marker sets  \
# 1    o__Bacteroidales (UID2654)       163       485           265
# 4    o__Bacteroidales (UID2654)       163       486           266
# 8                   root (UID1)      5656        56            24
# 9    o__Bacteroidales (UID2654)       163       486           266
# 16   o__Bacteroidales (UID2654)       163       486           266
# 48   o__Bacteroidales (UID2654)       163       486           266
# 49   o__Bacteroidales (UID2654)       163       486           266
# 60   o__Bacteroidales (UID2654)       163       486           266
# 64   o__Bacteroidales (UID2654)       163       486           266
# 65   o__Bacteroidales (UID2621)       198       427           260
# 69         k__Bacteria (UID203)      5449       104            58
# 71   o__Bacteroidales (UID2621)       198       427           260
# 104  o__Bacteroidales (UID2654)       163       485           265
# 143    g__Bacteroides (UID2691)        33       839           309
# 163    g__Bacteroides (UID2691)        33       839           309
# 164    g__Bacteroides (UID2691)        33       839           309
# 194    g__Bacteroides (UID2691)        33       839           309
# 10                  root (UID1)      5656        56            24
# 11         k__Bacteria (UID203)      5449       103            58
# 74   o__Bacteroidales (UID2654)       163       486           266
# 110    g__Bacteroides (UID2691)        33       839           309
# 112    g__Bacteroides (UID2691)        33       839           309
# 125        k__Bacteria (UID203)      5449       104            58
# 139  o__Bacteroidales (UID2657)       160       492           269
# 150    g__Bacteroides (UID2691)        33       839           309
# 151    g__Bacteroides (UID2691)        33       839           309
# 152  o__Bacteroidales (UID2654)       163       486           266
# 172        k__Bacteria (UID203)      5449       104            58
# 173    g__Bacteroides (UID2691)        33       839           309
# 174    g__Bacteroides (UID2691)        33       839           309
# 175        k__Bacteria (UID203)      5449       103            58
# 179  o__Bacteroidales (UID2657)       160       492           269
# 181        k__Bacteria (UID203)      5449       104            58
# 182    g__Bacteroides (UID2691)        33       839           309
# 187  o__Bacteroidales (UID2657)       160       492           269
# 188        k__Bacteria (UID203)      5449       103            58
# 189        k__Bacteria (UID203)      5449       103            58
# 191    g__Bacteroides (UID2691)        33       839           309
# 192    g__Bacteroides (UID2691)        33       839           309
# 195    g__Bacteroides (UID2691)        33       839           309
#
#      Completeness  Contamination  Strain heterogeneity  Plate Well Confirmed  \
# 1           99.25           0.00                  0.00      1  A02       Yes
# 4           99.25          23.05                 21.85      1  A05       Yes
# 8          100.00         100.46                 63.79      1  A09       Yes
# 9           99.25           0.00                  0.00      1  A10       Yes
# 16          99.25           0.00                  0.00      1  B05       Yes
# 48          99.25           0.76                 75.00      1  E01       Yes
# 49          99.25           0.05                  0.00      1  E02       Yes
# 60          99.25           0.00                  0.00      1  F01       Yes
# 64          99.25           0.31                  0.00      1  F05       Yes
# 65          99.42           4.56                  0.00      1  F06       Yes
# 69         100.00          28.45                 48.48      1  F09       Yes
# 71          99.23          18.83                 42.11      1  F11       Yes
# 104         99.25           1.51                  0.00      2  A06       Yes
# 143         99.46           6.68                 55.77      2  D08       Yes
# 163         99.35           0.91                 33.33      2  F05       Yes
# 164         99.41          11.04                 20.79      2  F06       Yes
# 194         99.46           6.25                  3.08      2  H10       Yes
# 10         100.00         107.23                 67.19      1  A11        No
# 11          93.97          82.62                 16.04      1  A12        No
# 74          99.25           0.67                  0.00      1  G02        No
# 110         99.41          56.70                 62.98      2  A12        No
# 112         99.46           2.70                 17.39      2  B02        No
# 125        100.00          87.99                 66.67      2  C02        No
# 139         99.26          15.95                 17.07      2  D04        No
# 150         98.81           1.99                  4.17      2  E03        No
# 151         99.46           3.16                  2.94      2  E04        No
# 152         99.25          11.03                 11.32      2  E06        No
# 172        100.00          68.84                 71.43      2  G01        No
# 173         99.41           0.32                  0.00      2  G02        No
# 174         98.81          44.18                 34.29      2  G03        No
# 175        100.00          42.88                 46.15      2  G04        No
# 179         99.26           2.78                  8.33      2  G08        No
# 181        100.00         169.09                 52.10      2  G10        No
# 182         99.46          23.78                 44.44      2  G11        No
# 187         99.26           7.17                 36.11      2  H04        No
# 188        100.00         259.29                 60.00      2  H05        No
# 189        100.00         259.29                 60.00      2  H05        No
# 191         99.46           5.73                 48.98      2  H07        No
# 192         98.81          13.11                 42.02      2  H08        No
# 195         99.46           6.25                  3.08      2  H10        No
#
#                Species_y    Strain_y  0    1    2   3   4  5+
# 1            B. vulgatus       WH019  2  483    0   0   0   0
# 4            B. vulgatus       WH515  2  380   98   5   1   0
# 8            B. vulgatus    VPI-4245  0    0   55   1   0   0
# 9               B. dorei   VPI-3776A  2  484    0   0   0   0
# 16           B. vulgatus       WH516  2  484    0   0   0   0
# 48           B. vulgatus     WH009ab  2  480    4   0   0   0
# 49           B. vulgatus       WH108  2  483    1   0   0   0
# 60           B. vulgatus       WH013  2  484    0   0   0   0
# 64              B. dorei       WH607  2  482    2   0   0   0
# 65         P. distasonis  VPI-C30-45  2  404   21   0   0   0
# 69              B. dorei   VPI-6598B  0   81   18   5   0   0
# 71         P. distasonis  VPI-BD6781  3  360   58   6   0   0
# 104          B. vulgatus       23673  2  476    7   0   0   0
# 143            B. ovatus       23736  3  786   49   1   0   0
# 163            B. ovatus       23621  4  826    9   0   0   0
# 164  B. thetaiotaomicron       23685  4  742   89   4   0   0
# 194  B. thetaiotaomicron  TS33APG1.1  3  777   56   3   0   0
# 10                   NaN         NaN  0    0   52   4   0   0
# 11                   NaN         NaN  4   20   70   6   3   0
# 74                   NaN         NaN  2  479    5   0   0   0
# 110                  NaN         NaN  4  413  380  39   2   1
# 112                  NaN         NaN  3  813   23   0   0   0
# 125                  NaN         NaN  0   34   63   7   0   0
# 139                  NaN         NaN  2  416   70   4   0   0
# 150                  NaN         NaN  6  809   24   0   0   0
# 151                  NaN         NaN  3  806   28   2   0   0
# 152                  NaN         NaN  2  439   41   4   0   0
# 172                  NaN         NaN  0   46   52   6   0   0
# 173                  NaN         NaN  4  832    3   0   0   0
# 174                  NaN         NaN  5  532  231  57  13   1
# 175                  NaN         NaN  0   66   31   5   1   0
# 179                  NaN         NaN  2  478   12   0   0   0
# 181                  NaN         NaN  0   14   46  31   9   4
# 182                  NaN         NaN  3  664  150  22   0   0
# 187                  NaN         NaN  2  456   33   1   0   0
# 188                  NaN         NaN  0   13   24  27  19  20
# 189                  NaN         NaN  0   13   24  27  19  20
# 191                  NaN         NaN  3  787   49   0   0   0
# 192                  NaN         NaN  5  723  107   4   0   0
# 195                  NaN         NaN  3  777   56   3   0   0

# %%
totcounts['Contamination'] += 0.001
sns.histplot(totcounts, x='Contamination', hue='Confirmed', log_scale=True, bins=15)
# plt.xscale('log')
# plt.yscale('log')
# Out:
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Contamination', ylabel='Count'>

# %%
sns.kdeplot(totcounts, x='Contamination', hue='Confirmed', log_scale=True)
# plt.xscale('log')
# plt.yscale('log')
# Out:
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Contamination', ylabel='Density'>

# %%
# totcounts['Contamination'] += 0.001
sns.histplot(totcounts, x='Completeness', hue='Confirmed',  bins=15)
# plt.xscale('log')
# plt.yscale('log')
# Out:
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Completeness', ylabel='Count'>

# %%
sns.histplot(totcounts, x='# genomes', hue='Confirmed', log_scale=True)
# plt.xscale('log')
# plt.yscale('log')
# Out:
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='# genomes', ylabel='Count'>

# %%
totcounts['5+'] += 0.0001
sns.histplot(totcounts, x='5+', hue='Confirmed', log_scale=True)
# plt.xscale('log')
# plt.yscale('log')
# Out:
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='5+', ylabel='Count'>

# %%
totcounts['4'] += 0.0001
sns.histplot(totcounts, x='4', hue='Confirmed', log_scale=True)
# plt.xscale('log')
# plt.yscale('log')
# Out:
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='4', ylabel='Count'>

# %%
totcounts['3'] += 0.0001
sns.histplot(totcounts, x='3', hue='Confirmed', log_scale=True)
# plt.xscale('log')
# plt.yscale('log')
# Out:
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='3', ylabel='Count'>

# %%
totcounts['3+'] = totcounts['3']+totcounts['4']+totcounts['5+']
sns.histplot(totcounts, x='3+', hue='Confirmed', log_scale=True)
# plt.xscale('log')
# plt.yscale('log')
# Out:
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='3+', ylabel='Count'>

# %%
totcounts['4+'] = totcounts['4']+totcounts['5+']
sns.histplot(totcounts, x='4+', hue='Confirmed', log_scale=True)
# plt.xscale('log')
# plt.yscale('log')
# Out:
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='4+', ylabel='Count'>

# %%
df4 = df2.copy(deep=True)
df4['Strain heterogeneity'] += 0.0001
# df4['Contamination_pdt'] = df4['Contamination']*(1-(df4['Strain heterogeneity']/100))
df4['Contamination_pdt'] = (df4['Contamination']/df4['Completeness'])/((df4['Strain heterogeneity']))
# HOW DO I NEED TO TRANSFORM???
df4
# Out:
#                  Marker lineage # genomes # markers # marker sets  \
# 0    o__Bacteroidales (UID2657)       160       491           269
# 1    o__Bacteroidales (UID2654)       163       485           265
# 2      g__Bacteroides (UID2691)        33       839           309
# 3      g__Bacteroides (UID2691)        33       839           309
# 4    o__Bacteroidales (UID2654)       163       486           266
# ..                          ...       ...       ...           ...
# 193    g__Bacteroides (UID2691)        33       839           309
# 194    g__Bacteroides (UID2691)        33       839           309
# 195    g__Bacteroides (UID2691)        33       839           309
# 196    g__Bacteroides (UID2691)        33       839           309
# 197    g__Bacteroides (UID2691)        33       839           309
#
#      Completeness  Contamination  Strain heterogeneity  Plate Well  Confirmed  \
# 0           99.26           2.01               30.0001      1  NaN        NaN
# 1           99.25           0.00                0.0001      1  A02        1.0
# 2           99.46           0.02                0.0001      1  NaN        NaN
# 3           99.14           1.96               47.0601      1  NaN        NaN
# 4           99.25          23.05               21.8501      1  A05        1.0
# ..            ...            ...                   ...    ...  ...        ...
# 193         98.81           5.40               33.3301      2  NaN        NaN
# 194         99.46           6.25                3.0801      2  H10        1.0
# 195         99.46           6.25                3.0801      2  H10       10.0
# 196         99.41           0.25                0.0001      2  NaN        NaN
# 197         99.41           1.34               16.6701      2  NaN        NaN
#
#                Species_y    Strain_y  0    1   2  3  4 5+  Contamination_pdt
# 0                    NaN         NaN  2  481   7  1  0  0           0.000675
# 1            B. vulgatus       WH019  2  483   0  0  0  0           0.000000
# 2                    NaN         NaN  3  835   1  0  0  0           2.010859
# 3                    NaN         NaN  4  818  17  0  0  0           0.000420
# 4            B. vulgatus       WH515  2  380  98  5  1  0           0.010629
# ..                   ...         ... ..  ...  .. .. .. ..                ...
# 193                  NaN         NaN  5  779  54  1  0  0           0.001640
# 194  B. thetaiotaomicron  TS33APG1.1  3  777  56  3  0  0           0.020402
# 195                  NaN         NaN  3  777  56  3  0  0           0.020402
# 196                  NaN         NaN  4  831   4  0  0  0          25.148375
# 197                  NaN         NaN  4  823  12  0  0  0           0.000809
#
# [198 rows x 19 columns]

# %%
sns.scatterplot(df4, y='Confirmed', x='Contamination_pdt', hue='Marker lineage', legend=True)
plt.xscale('log')
plt.yscale('log')

# %%
sns.scatterplot(df4, y='Confirmed', x='5+', hue='Marker lineage', legend=True)
# plt.xscale('log')
# plt.yscale('log')
# Out:
# <Axes: xlabel='5+', ylabel='Confirmed'>

# %%
df4['Contamination_pdt'] += 0.0001
sns.histplot(df4, x='Contamination_pdt', log_scale=True, hue='Confirmed', bins=15)
# Out:
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Contamination_pdt', ylabel='Count'>
